# %% [markdown]
# ### Dataset Exploration - Metadata

# %% [markdown]
# 1. Imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

plt.style.use("ggplot")

# %% [markdown]
# 2. Dataset Overview

# %%
df = pd.read_csv(
    "../data/raw/METABRIC_RNA_Mutation.csv",
    low_memory=False
)
print(f"Rows (patients): {df.shape[0]}")
print(f"Columns (features): {df.shape[1]}")
df.info()

# %% [markdown]
#     Dataset Overview Results
#     - Rows (patients): 1904
#     - Columns (features): 693
#     - Datatypes: float64 (498), int64 (5), str (190)
#     - Memory usage: 10.1+ MB

# %% [markdown]
# 3. Missing Values

# %%
missing = df.isnull().sum()
missing = missing[missing > 0].sort_values(ascending=False)
missing.head(20)

# %% [markdown]
# 4. Column Names

# %%
for i, col in enumerate(df.columns):
    print(i, col)

# %% [markdown]
# 5. Survival Check

# %%
df[["overall_survival_months", "overall_survival"]].describe()
df["overall_survival"].value_counts()
df["overall_survival"].value_counts(normalize=True) * 100

# %% [markdown]
#     Survival Check Results
#     - 0 (event did not occur) → 57.9%
#     - 1 → 42.1%
#
#     So, approximately 801 deaths, and 1103 censored (i.e., alive at last follow-up) patients.
